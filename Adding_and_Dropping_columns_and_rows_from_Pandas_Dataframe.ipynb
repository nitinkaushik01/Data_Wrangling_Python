# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv')
data
# Out:
#    Customer ID Customer Name Product ID Product Cost
# 0            1          John       P001         $234
# 1            2      Patricia       P002       $1,456
# 2            3        Larsen       P003       $2,456
# 3            4          Noel       P004       $8,975
# 4            5      Leonardo       P005         $345
# 5            6          Paul       P006         $908

# %%
data['Data of Purchase'] = ['2018/02/03', '2017/09/11','2016/05/08','2015/06/06','2017/05/05', '2019/01/01']
data
# Out:
#    Customer ID Customer Name Product ID Product Cost Data of Purchase
# 0            1          John       P001         $234       2018/02/03
# 1            2      Patricia       P002       $1,456       2017/09/11
# 2            3        Larsen       P003       $2,456       2016/05/08
# 3            4          Noel       P004       $8,975       2015/06/06
# 4            5      Leonardo       P005         $345       2017/05/05
# 5            6          Paul       P006         $908       2019/01/01

# %%
data.assign(Location = ['NewYork','San Francisco','Dallas','New Jersey','Atlanta','Madison'])
# Out:
#    Customer ID Customer Name Product ID Product Cost Data of Purchase  \
# 0            1          John       P001         $234       2018/02/03
# 1            2      Patricia       P002       $1,456       2017/09/11
# 2            3        Larsen       P003       $2,456       2016/05/08
# 3            4          Noel       P004       $8,975       2015/06/06
# 4            5      Leonardo       P005         $345       2017/05/05
# 5            6          Paul       P006         $908       2019/01/01
#
#         Location
# 0        NewYork
# 1  San Francisco
# 2         Dallas
# 3     New Jersey
# 4        Atlanta
# 5        Madison

# %%
data = data.drop('Data of Purchase', axis=1)
data
# Out:
#    Customer ID Customer Name Product ID Product Cost
# 0            1          John       P001         $234
# 1            2      Patricia       P002       $1,456
# 2            3        Larsen       P003       $2,456
# 3            4          Noel       P004       $8,975
# 4            5      Leonardo       P005         $345
# 5            6          Paul       P006         $908

# %%
data
# Out:
#    Customer ID Customer Name Product ID Product Cost
# 0            1          John       P001         $234
# 1            2      Patricia       P002       $1,456
# 2            3        Larsen       P003       $2,456
# 3            4          Noel       P004       $8,975
# 4            5      Leonardo       P005         $345
# 5            6          Paul       P006         $908

# %%
data[:2]
# Out:
#    Customer ID Customer Name Product ID Product Cost
# 0            1          John       P001         $234
# 1            2      Patricia       P002       $1,456

# %%
data
# Out:
#    Customer ID Customer Name Product ID Product Cost
# 0            1          John       P001         $234
# 1            2      Patricia       P002       $1,456
# 2            3        Larsen       P003       $2,456
# 3            4          Noel       P004       $8,975
# 4            5      Leonardo       P005         $345
# 5            6          Paul       P006         $908

# %%
data1 = data.drop(data.index[1])
# Out:
#    Customer ID Customer Name Product ID Product Cost
# 0            1          John       P001         $234
# 2            3        Larsen       P003       $2,456
# 3            4          Noel       P004       $8,975
# 4            5      Leonardo       P005         $345
# 5            6          Paul       P006         $908

# %%
data
# Out:
#    Customer ID Customer Name Product ID Product Cost
# 0            1          John       P001         $234
# 1            2      Patricia       P002       $1,456
# 2            3        Larsen       P003       $2,456
# 3            4          Noel       P004       $8,975
# 4            5      Leonardo       P005         $345
# 5            6          Paul       P006         $908

# %%
data1 = data.drop(data.index[[3,5]])
data1
# Out:
#    Customer ID Customer Name Product ID Product Cost
# 0            1          John       P001         $234
# 1            2      Patricia       P002       $1,456
# 2            3        Larsen       P003       $2,456
# 4            5      Leonardo       P005         $345

# %%
data
# Out:
#    Customer ID Customer Name Product ID Product Cost
# 0            1          John       P001         $234
# 1            2      Patricia       P002       $1,456
# 2            3        Larsen       P003       $2,456
# 3            4          Noel       P004       $8,975
# 4            5      Leonardo       P005         $345
# 5            6          Paul       P006         $908

# %%
data2 = data.drop(data.index[-4])
data2
# Out:
#    Customer ID Customer Name Product ID Product Cost
# 0            1          John       P001         $234
# 1            2      Patricia       P002       $1,456
# 3            4          Noel       P004       $8,975
# 4            5      Leonardo       P005         $345
# 5            6          Paul       P006         $908

# %%
data
# Out:
#    Customer ID Customer Name Product ID Product Cost
# 0            1          John       P001         $234
# 1            2      Patricia       P002       $1,456
# 2            3        Larsen       P003       $2,456
# 3            4          Noel       P004       $8,975
# 4            5      Leonardo       P005         $345
# 5            6          Paul       P006         $908

# %%
data3 = data[:-2]
data3
# Out:
#    Customer ID Customer Name Product ID Product Cost
# 0            1          John       P001         $234
# 1            2      Patricia       P002       $1,456
# 2            3        Larsen       P003       $2,456
# 3            4          Noel       P004       $8,975
